# %%
class parent:
    def test_parent(self):
        print("this is my parent class")

# %%
class child(parent):
    pass

# %%
child_obj = child()

# %%
child_obj.test_parent()
# Out:
# this is my parent class

# %% [markdown]
# ### Multi level Inheritance
# ![Screenshot%20Capture%20-%202023-09-19%20-%2010-56-55.png](attachment:Screenshot%20Capture%20-%202023-09-19%20-%2010-56-55.png)

# %%
class class1 :
    def test_class1(self) :
        print("this is class 1")

# %%
class class2(class1):
    def test_class2(self):
        print("this is my class 2")

# %%
class class3(class2):
    def test_class3(self):
        print("this is my class 3")

# %%
obj_class3 = class3()

# %%
obj_class3.test_class1()
# Out:
# this is class 1

# %%
obj_class3.test_class2()
# Out:
# this is my class 2

# %%
obj_class3.test_class3()
# Out:
# this is my class 3

# %% [markdown]
# ![Screenshot%20Capture%20-%202023-09-19%20-%2011-01-56.png](attachment:Screenshot%20Capture%20-%202023-09-19%20-%2011-01-56.png)

# %% [markdown]
# ### MULTIPLE INHERITANCE

# %%
class class1 :
    def test_class1(self) :
        print("this is class 1")

# %%
class class2 :
    def test_class2(self) :
        print("this is class 2")

# %%
class class3(class1, class2) :
    pass

# %%
obj_class3= class3()

# %%
obj_class3.test_class1()
# Out:
# this is class 1

# %%
obj_class3.test_class2()
# Out:
# this is class 2

# %% [markdown]
# ![Screenshot%20Capture%20-%202023-09-19%20-%2011-05-59.png](attachment:Screenshot%20Capture%20-%202023-09-19%20-%2011-05-59.png)
